# %%
# SPDX-License-Identifier: MIT
# Copyright (c) 2025 Hammerheads Engineers sp. z o.o.
# Author: Aleksander Stanik
import sys
import os
import time
import yaml
import json
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

current_dir = os.getcwd()
repo_root = os.path.abspath(os.path.join(current_dir, '..'))

if repo_root not in sys.path:
    sys.path.append(repo_root)


import spx_python
spx_python.set_global_transparent(False)
# Initialize HTTP-based SPX client wrapper pointing to local SPX server
product_key = os.environ['SPX_PRODUCT_KEY']
wrapper = spx_python.init(address='http://localhost:8000',
                                product_key=product_key)

# %%
# Create a new model for the PT100 sensor
pt_100_yaml = '''
attributes:
  temperature: 0.0
actions:
    - { saw: $attr(temperature), stop_value: 14, period: 5 }
    - { ramp: $attr(temperature), stop_value: 150, duration: 5, type: overshoot, overshoot: 5 }
    - { noise: $ext(temperature), std: 0.01, mode: proportional }
'''
# Parse YAML and build the model
data = yaml.safe_load(pt_100_yaml)
wrapper["models"]["pt_100"] = data
wrapper["instances"].clear()
wrapper["instances"]["test_pt_100"] = "pt_100"
instance = wrapper["instances"]["test_pt_100"]

print("Available models:", wrapper["models"].keys())
print("Available instances:", wrapper["instances"].keys())

print("Instances", wrapper["instances"])
# Out:
# Available models: ['TemperatureSensor', 'PowerSupply', 'PIDController', 'pt_100']
# Available instances: ['test_pt_100']
# Instances {
#   "name": "instances",
#   "attr": {
#     "definition": {
#       "type": "list",
#       "items": [
#         {
#           "type": "dict",
#           "value": {
#             "foo_inst": "foo"
#           }
#         }
#       ]
#     },
#     "destroyed": {
#       "type": "bool",
#       "value": false,
#       "is_property": true,
#       "has_setter": false
#     },
#     "enabled": {
#       "type": "bool",
#       "value": true,
#       "is_property": true,
#       "has_setter": true
#     },
#     "hooks": {
#       "type": "dict",
#       "value": {}
#     },
#     "logger": {
#       "type": "Logger",
#       "value": "<non-serializable: Logger>"
#     },
#     "name": {
#       "type": "str",
#       "value": "instances"
#     },
#     "parent": {
#       "type": "SpxComponent",
#       "name": "system"
#     },
#     "state": {
#       "type": "SpxComponentState",
#       "value": "RUNNING"
#     }
#   },
#   "method": {
#     "add": {
#       "type": "method",
#       "parameters": {
#         "inst_name": "inst_name: str",
#         "cfg": "cfg: Any"
#       },
#       "doc": "\n        Dynamically add a new instance at runtime, mirroring _populate logic for a single entry.\n        Returns the newly created component (or existing if already present).\n        "
#     },
#     "add_child": {
#       "type": "method",
#       "parameters": {
#         "child": "child: 'SpxComponent'"
#       },
#       "doc": "Prevent adding itself as a child"
#     },
#     "close": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Convenience alias for destroy() to support 'with' or resource idioms."
#     },
#     "delete_child": {
#       "type": "method",
#       "parameters": {
#         "child": "child: 'SpxComponent'"
#       },
#       "doc": "Destroy and remove a child component by reference."
#     },
#     "destroy": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Deep-destroy the component and all descendants.\n\n        This method is idempotent:\n        - Subsequent calls after the first successful destroy() are no-ops.\n        Cleanup order:\n        1) Transition \u2192 DESTROYING\n        2) Stop this component (best-effort) and trigger on_destroy hooks\n        3) Recursively destroy children (snapshot to avoid mutation while iterating)\n        4) Detach from parent\n        5) Call release() hook\n        6) Clear hooks/children references\n        7) Transition \u2192 DESTROYED\n        "
#     },
#     "disable": {
#       "type": "method",
#       "parameters": {},
#       "doc": "\n        Disable the component. Lifecycle methods (prepare, run, start, stop)\n        become no-ops when the component is disabled.\n        "
#     },
#     "enable": {
#       "type": "method",
#       "parameters": {},
#       "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#     },
#     "get": {
#       "type": "method",
#       "parameters": {
#         "key": "key: str",
#         "default": "default=None"
#       },
#       "doc": "\n        Get a child component by name, returning a default if not found.\n\n        Args:\n            key (str): Name of the child component.\n            default (Any): Value to return if the child is not found.\n\n        Returns:\n            Optional[SpxComponent]: The child component or the default.\n        "
#     },
#     "get_children": {
#       "type": "method",
#       "parameters": {},
#       "doc": "Return the internal dict of children keyed by name."
#     },
#     "get_children_list": {
#       "type": "method",
#       "parameters": {},
#       "doc": "Return a list of child components."
#     },
#     "get_hierarchy": {
#       "type": "method",
#       "parameters": {},
#       "doc": null
#     },
#     "get_hooks": {
#       "type": "method",
#       "parameters": {
#         "event": "event: str"
#       },
#       "doc": "\n        Get all registered hook components for the given event name.\n        "
#     },
#     "get_parent": {
#       "type": "method",
#       "parameters": {},
#       "doc": null
#     },
#     "get_path": {
#       "type": "method",
#       "parameters": {
#         "delimiter": "delimiter: str = '/'"
#       },
#       "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#     },
#     "get_root": {
#       "type": "method",
#       "parameters": {},
#       "doc": null
#     },
#     "pause": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Pause the component and propagate to children."
#     },
#     "prepare": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Prepare the component and propagate to children."
#     },
#     "register_hook": {
#       "type": "method",
#       "parameters": {
#         "event": "event: str",
#         "hook_component": "hook_component: 'SpxComponent'"
#       },
#       "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#     },
#     "release": {
#       "type": "method",
#       "parameters": {},
#       "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#     },
#     "remove": {
#       "type": "method",
#       "parameters": {
#         "inst_name": "inst_name: str"
#       },
#       "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#     },
#     "remove_child": {
#       "type": "method",
#       "parameters": {
#         "child": "child: 'SpxComponent'"
#       },
#       "doc": null
#     },
#     "reset": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Reset the component and propagate to children."
#     },
#     "run": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Run the component and propagate to children."
#     },
#     "start": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Start the component and propagate to children."
#     },
#     "stop": {
#       "type": "method",
#       "parameters": {
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "Stop the component and propagate to children."
#     },
#     "trigger_hooks": {
#       "type": "method",
#       "parameters": {
#         "event": "event: str",
#         "args": "*args",
#         "kwargs": "**kwargs"
#       },
#       "doc": "\n        Invoke all hooks registered under the given event.\n        Failures are emitted as diagnostics (bubble=False) and do not break lifecycle.\n        "
#     },
#     "update": {
#       "type": "method",
#       "parameters": {
#         "cfg": "cfg: Union[Dict, List]"
#       },
#       "doc": "Forwards to the subclass hook _populate."
#     }
#   },
#   "children": [
#     {
#       "name": "test_pt_100",
#       "attr": {
#         "definition": {
#           "type": "dict",
#           "value": {}
#         },
#         "destroyed": {
#           "type": "bool",
#           "value": false,
#           "is_property": true,
#           "has_setter": false
#         },
#         "enabled": {
#           "type": "bool",
#           "value": true,
#           "is_property": true,
#           "has_setter": true
#         },
#         "hooks": {
#           "type": "dict",
#           "value": {}
#         },
#         "logger": {
#           "type": "Logger",
#           "value": "<non-serializable: Logger>"
#         },
#         "model": {
#           "type": "str",
#           "value": "pt_100"
#         },
#         "name": {
#           "type": "str",
#           "value": "test_pt_100"
#         },
#         "parent": {
#           "type": "NoneType",
#           "value": null
#         },
#         "real_time": {
#           "type": "bool",
#           "value": true
#         },
#         "state": {
#           "type": "SpxComponentState",
#           "value": "INITIALIZED"
#         },
#         "uid": {
#           "type": "str",
#           "value": "14ea149a-a702-4f11-8abd-adb1a3f0c2b9"
#         }
#       },
#       "method": {
#         "add": {
#           "type": "method",
#           "parameters": {
#             "inst_name": "inst_name: str",
#             "cfg": "cfg: Any"
#           },
#           "doc": "\n        Dynamically add a new instance at runtime, mirroring _populate logic for a single entry.\n        Returns the newly created component (or existing if already present).\n        "
#         },
#         "add_child": {
#           "type": "method",
#           "parameters": {
#             "child": "child: 'SpxComponent'"
#           },
#           "doc": "Prevent adding itself as a child"
#         },
#         "close": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Convenience alias for destroy() to support 'with' or resource idioms."
#         },
#         "delete_child": {
#           "type": "method",
#           "parameters": {
#             "child": "child: 'SpxComponent'"
#           },
#           "doc": "Destroy and remove a child component by reference."
#         },
#         "destroy": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Deep-destroy the component and all descendants.\n\n        This method is idempotent:\n        - Subsequent calls after the first successful destroy() are no-ops.\n        Cleanup order:\n        1) Transition \u2192 DESTROYING\n        2) Stop this component (best-effort) and trigger on_destroy hooks\n        3) Recursively destroy children (snapshot to avoid mutation while iterating)\n        4) Detach from parent\n        5) Call release() hook\n        6) Clear hooks/children references\n        7) Transition \u2192 DESTROYED\n        "
#         },
#         "disable": {
#           "type": "method",
#           "parameters": {},
#           "doc": "\n        Disable the component. Lifecycle methods (prepare, run, start, stop)\n        become no-ops when the component is disabled.\n        "
#         },
#         "enable": {
#           "type": "method",
#           "parameters": {},
#           "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#         },
#         "get": {
#           "type": "method",
#           "parameters": {
#             "key": "key: str",
#             "default": "default=None"
#           },
#           "doc": "\n        Get a child component by name, returning a default if not found.\n\n        Args:\n            key (str): Name of the child component.\n            default (Any): Value to return if the child is not found.\n\n        Returns:\n            Optional[SpxComponent]: The child component or the default.\n        "
#         },
#         "get_children": {
#           "type": "method",
#           "parameters": {},
#           "doc": "Return the internal dict of children keyed by name."
#         },
#         "get_children_list": {
#           "type": "method",
#           "parameters": {},
#           "doc": "Return a list of child components."
#         },
#         "get_hierarchy": {
#           "type": "method",
#           "parameters": {},
#           "doc": null
#         },
#         "get_hooks": {
#           "type": "method",
#           "parameters": {
#             "event": "event: str"
#           },
#           "doc": "\n        Get all registered hook components for the given event name.\n        "
#         },
#         "get_parent": {
#           "type": "method",
#           "parameters": {},
#           "doc": null
#         },
#         "get_path": {
#           "type": "method",
#           "parameters": {
#             "delimiter": "delimiter: str = '/'"
#           },
#           "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#         },
#         "get_root": {
#           "type": "method",
#           "parameters": {},
#           "doc": null
#         },
#         "pause": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Pause the component and propagate to children."
#         },
#         "prepare": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Prepare the component and propagate to children."
#         },
#         "register_hook": {
#           "type": "method",
#           "parameters": {
#             "event": "event: str",
#             "hook_component": "hook_component: 'SpxComponent'"
#           },
#           "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#         },
#         "release": {
#           "type": "method",
#           "parameters": {},
#           "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#         },
#         "remove": {
#           "type": "method",
#           "parameters": {
#             "inst_name": "inst_name: str"
#           },
#           "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#         },
#         "remove_child": {
#           "type": "method",
#           "parameters": {
#             "child": "child: 'SpxComponent'"
#           },
#           "doc": null
#         },
#         "reset": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Reset the component and propagate to children."
#         },
#         "run": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Run the component and propagate to children."
#         },
#         "start": {
#           "type": "method",
#           "parameters": {},
#           "doc": "\n        Start the model's timer and polling mechanisms.\n        "
#         },
#         "stop": {
#           "type": "method",
#           "parameters": {
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "Stop the component and propagate to children."
#         },
#         "trigger_hooks": {
#           "type": "method",
#           "parameters": {
#             "event": "event: str",
#             "args": "*args",
#             "kwargs": "**kwargs"
#           },
#           "doc": "\n        Invoke all hooks registered under the given event.\n        Failures are emitted as diagnostics (bubble=False) and do not break lifecycle.\n        "
#         },
#         "update": {
#           "type": "method",
#           "parameters": {
#             "cfg": "cfg: Union[Dict, List]"
#           },
#           "doc": "Forwards to the subclass hook _populate."
#         }
#       },
#       "children": [
#         {
#           "name": "attributes",
#           "attr": {
#             "definition": {
#               "type": "dict",
#               "value": {}
#             },
#             "destroyed": {
#               "type": "bool",
#               "value": false,
#               "is_property": true,
#               "has_setter": false
#             },
#             "enabled": {
#               "type": "bool",
#               "value": true,
#               "is_property": true,
#               "has_setter": true
#             },
#             "external": {
#               "type": "ExternalValue",
#               "value": "<non-serializable: ExternalValue>"
#             },
#             "hooks": {
#               "type": "dict",
#               "value": {}
#             },
#             "internal": {
#               "type": "InternalValue",
#               "value": "<non-serializable: InternalValue>"
#             },
#             "logger": {
#               "type": "Logger",
#               "value": "<non-serializable: Logger>"
#             },
#             "name": {
#               "type": "str",
#               "value": "attributes"
#             },
#             "parent": {
#               "type": "SpxComponent",
#               "name": "test_pt_100"
#             },
#             "state": {
#               "type": "SpxComponentState",
#               "value": "INITIALIZED"
#             }
#           },
#           "method": {
#             "add": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str",
#                 "cfg": "cfg: Any"
#               },
#               "doc": "\n        Dynamically add a new instance at runtime, mirroring _populate logic for a single entry.\n        Returns the newly created component (or existing if already present).\n        "
#             },
#             "add_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": "Prevent adding itself as a child"
#             },
#             "close": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Convenience alias for destroy() to support 'with' or resource idioms."
#             },
#             "delete_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": "Destroy and remove a child component by reference."
#             },
#             "destroy": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Deep-destroy the component and all descendants.\n\n        This method is idempotent:\n        - Subsequent calls after the first successful destroy() are no-ops.\n        Cleanup order:\n        1) Transition \u2192 DESTROYING\n        2) Stop this component (best-effort) and trigger on_destroy hooks\n        3) Recursively destroy children (snapshot to avoid mutation while iterating)\n        4) Detach from parent\n        5) Call release() hook\n        6) Clear hooks/children references\n        7) Transition \u2192 DESTROYED\n        "
#             },
#             "disable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Disable the component. Lifecycle methods (prepare, run, start, stop)\n        become no-ops when the component is disabled.\n        "
#             },
#             "enable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#             },
#             "get": {
#               "type": "method",
#               "parameters": {
#                 "key": "key: str",
#                 "default": "default=None"
#               },
#               "doc": "\n        Get a child component by name, returning a default if not found.\n\n        Args:\n            key (str): Name of the child component.\n            default (Any): Value to return if the child is not found.\n\n        Returns:\n            Optional[SpxComponent]: The child component or the default.\n        "
#             },
#             "get_children": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return the internal dict of children keyed by name."
#             },
#             "get_children_list": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return a list of child components."
#             },
#             "get_hierarchy": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str"
#               },
#               "doc": "\n        Get all registered hook components for the given event name.\n        "
#             },
#             "get_parent": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_path": {
#               "type": "method",
#               "parameters": {
#                 "delimiter": "delimiter: str = '/'"
#               },
#               "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#             },
#             "get_root": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "pause": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Pause the component and propagate to children."
#             },
#             "prepare": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Prepare the component and propagate to children."
#             },
#             "register_hook": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "hook_component": "hook_component: 'SpxComponent'"
#               },
#               "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#             },
#             "release": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#             },
#             "remove": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str"
#               },
#               "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#             },
#             "remove_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": null
#             },
#             "reset": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Reset the component and propagate to children."
#             },
#             "run": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Run the component and propagate to children."
#             },
#             "start": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Start the component and propagate to children."
#             },
#             "stop": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Stop the component and propagate to children."
#             },
#             "trigger_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Invoke all hooks registered under the given event.\n        Failures are emitted as diagnostics (bubble=False) and do not break lifecycle.\n        "
#             },
#             "update": {
#               "type": "method",
#               "parameters": {
#                 "cfg": "cfg: Union[Dict, List]"
#               },
#               "doc": "Forwards to the subclass hook _populate."
#             }
#           },
#           "children": [
#             {
#               "name": "temperature",
#               "attr": {
#                 "definition": {
#                   "type": "float",
#                   "value": 0.0
#                 },
#                 "destroyed": {
#                   "type": "bool",
#                   "value": false,
#                   "is_property": true,
#                   "has_setter": false
#                 },
#                 "enabled": {
#                   "type": "bool",
#                   "value": true,
#                   "is_property": true,
#                   "has_setter": true
#                 },
#                 "external": {
#                   "type": "ExternalAttributeWrapper",
#                   "value": "<non-serializable: ExternalAttributeWrapper>",
#                   "is_property": true,
#                   "has_setter": false
#                 },
#                 "external_value": {
#                   "type": "float",
#                   "value": 0.0,
#                   "is_property": true,
#                   "has_setter": true
#                 },
#                 "hooks": {
#                   "type": "dict",
#                   "value": {}
#                 },
#                 "initial_value": {
#                   "type": "float",
#                   "value": 0.0
#                 },
#                 "internal": {
#                   "type": "InternalAttributeWrapper",
#                   "value": "<non-serializable: InternalAttributeWrapper>",
#                   "is_property": true,
#                   "has_setter": false
#                 },
#                 "internal_value": {
#                   "type": "float",
#                   "value": 0.0,
#                   "is_property": true,
#                   "has_setter": true
#                 },
#                 "logger": {
#                   "type": "Logger",
#                   "value": "<non-serializable: Logger>"
#                 },
#                 "name": {
#                   "type": "str",
#                   "value": "temperature"
#                 },
#                 "parent": {
#                   "type": "SpxComponent",
#                   "name": "attributes"
#                 },
#                 "state": {
#                   "type": "SpxComponentState",
#                   "value": "INITIALIZED"
#                 },
#                 "type": {
#                   "type": "str",
#                   "value": "float"
#                 },
#                 "unit": {
#                   "type": "NoneType",
#                   "value": null
#                 }
#               },
#               "method": {
#                 "add": {
#                   "type": "method",
#                   "parameters": {
#                     "inst_name": "inst_name: str",
#                     "cfg": "cfg: Any"
#                   },
#                   "doc": "\n        Dynamically add a new instance at runtime, mirroring _populate logic for a single entry.\n        Returns the newly created component (or existing if already present).\n        "
#                 },
#                 "add_child": {
#                   "type": "method",
#                   "parameters": {
#                     "child": "child: 'SpxComponent'"
#                   },
#                   "doc": "Prevent adding itself as a child"
#                 },
#                 "close": {
#                   "type": "method",
#                   "parameters": {
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "Convenience alias for destroy() to support 'with' or resource idioms."
#                 },
#                 "delete_child": {
#                   "type": "method",
#                   "parameters": {
#                     "child": "child: 'SpxComponent'"
#                   },
#                   "doc": "Destroy and remove a child component by reference."
#                 },
#                 "destroy": {
#                   "type": "method",
#                   "parameters": {
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "Deep-destroy the component and all descendants.\n\n        This method is idempotent:\n        - Subsequent calls after the first successful destroy() are no-ops.\n        Cleanup order:\n        1) Transition \u2192 DESTROYING\n        2) Stop this component (best-effort) and trigger on_destroy hooks\n        3) Recursively destroy children (snapshot to avoid mutation while iterating)\n        4) Detach from parent\n        5) Call release() hook\n        6) Clear hooks/children references\n        7) Transition \u2192 DESTROYED\n        "
#                 },
#                 "disable": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": "\n        Disable the component. Lifecycle methods (prepare, run, start, stop)\n        become no-ops when the component is disabled.\n        "
#                 },
#                 "enable": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#                 },
#                 "get": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": "Return the internal value."
#                 },
#                 "get_children": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": "Return the internal dict of children keyed by name."
#                 },
#                 "get_children_list": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": "Return a list of child components."
#                 },
#                 "get_hierarchy": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "get_hooks": {
#                   "type": "method",
#                   "parameters": {
#                     "event": "event: str"
#                   },
#                   "doc": "\n        Get all registered hook components for the given event name.\n        "
#                 },
#                 "get_parent": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "get_path": {
#                   "type": "method",
#                   "parameters": {
#                     "delimiter": "delimiter: str = '/'"
#                   },
#                   "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#                 },
#                 "get_root": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "get_wrapper": {
#                   "type": "method",
#                   "parameters": {
#                     "wrapper_type": "wrapper_type: str"
#                   },
#                   "doc": "\n        Return the corresponding attribute wrapper by name.\n\n        Args:\n            wrapper_type (str): 'internal' or 'external'.\n\n        Returns:\n            InternalAttribute or ExternalAttribute wrapper instance.\n        "
#                 },
#                 "link_to_external_func": {
#                   "type": "method",
#                   "parameters": {
#                     "instance": "instance",
#                     "getter": "getter",
#                     "setter": "setter=None"
#                   },
#                   "doc": null
#                 },
#                 "link_to_external_property": {
#                   "type": "method",
#                   "parameters": {
#                     "instance": "instance",
#                     "property_name": "property_name"
#                   },
#                   "doc": null
#                 },
#                 "link_to_internal_func": {
#                   "type": "method",
#                   "parameters": {
#                     "instance": "instance",
#                     "getter": "getter",
#                     "setter": "setter=None"
#                   },
#                   "doc": null
#                 },
#                 "link_to_internal_property": {
#                   "type": "method",
#                   "parameters": {
#                     "instance": "instance",
#                     "property_name": "property_name"
#                   },
#                   "doc": null
#                 },
#                 "pause": {
#                   "type": "method",
#                   "parameters": {
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "Pause the component and propagate to children."
#                 },
#                 "prepare": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "register_hook": {
#                   "type": "method",
#                   "parameters": {
#                     "event": "event: str",
#                     "hook_component": "hook_component: 'SpxComponent'"
#                   },
#                   "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#                 },
#                 "release": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#                 },
#                 "remove": {
#                   "type": "method",
#                   "parameters": {
#                     "inst_name": "inst_name: str"
#                   },
#                   "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#                 },
#                 "remove_child": {
#                   "type": "method",
#                   "parameters": {
#                     "child": "child: 'SpxComponent'"
#                   },
#                   "doc": null
#                 },
#                 "reset": {
#                   "type": "method",
#                   "parameters": {
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "Reset the component and propagate to children."
#                 },
#                 "run": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "set": {
#                   "type": "method",
#                   "parameters": {
#                     "value": "value"
#                   },
#                   "doc": "Set the internal value."
#                 },
#                 "start": {
#                   "type": "method",
#                   "parameters": {
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "Start the component and propagate to children."
#                 },
#                 "stop": {
#                   "type": "method",
#                   "parameters": {
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "Stop the component and propagate to children."
#                 },
#                 "trigger_hooks": {
#                   "type": "method",
#                   "parameters": {
#                     "event": "event: str",
#                     "args": "*args",
#                     "kwargs": "**kwargs"
#                   },
#                   "doc": "\n        Invoke all hooks registered under the given event.\n        Failures are emitted as diagnostics (bubble=False) and do not break lifecycle.\n        "
#                 },
#                 "unlink_external_property": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "unlink_internal_property": {
#                   "type": "method",
#                   "parameters": {},
#                   "doc": null
#                 },
#                 "update": {
#                   "type": "method",
#                   "parameters": {
#                     "cfg": "cfg: Union[Dict, List]"
#                   },
#                   "doc": "Forwards to the subclass hook _populate."
#                 }
#               },
#               "children": []
#             }
#           ]
#         },
#         {
#           "name": "actions",
#           "attr": {
#             "definition": {
#               "type": "list",
#               "items": [
#                 {
#                   "type": "dict",
#                   "value": {
#                     "saw": "$attr(temperature)",
#                     "stop_value": 14,
#                     "period": 5
#                   }
#                 },
#                 {
#                   "type": "dict",
#                   "value": {
#                     "ramp": "$attr(temperature)",
#                     "stop_value": 150,
#                     "duration": 5,
#                     "type": "overshoot",
#                     "overshoot": 5
#                   }
#                 },
#                 {
#                   "type": "dict",
#                   "value": {
#                     "noise": "$ext(temperature)",
#                     "std": 0.01,
#                     "mode": "proportional"
#                   }
#                 }
#               ]
#             },
#             "destroyed": {
#               "type": "bool",
#               "value": false,
#               "is_property": true,
#               "has_setter": false
#             },
#             "enabled": {
#               "type": "bool",
#               "value": true,
#               "is_property": true,
#               "has_setter": true
#             },
#             "hooks": {
#               "type": "dict",
#               "value": {}
#             },
#             "logger": {
#               "type": "Logger",
#               "value": "<non-serializable: Logger>"
#             },
#             "name": {
#               "type": "str",
#               "value": "actions"
#             },
#             "parent": {
#               "type": "SpxComponent",
#               "name": "test_pt_100"
#             },
#             "state": {
#               "type": "SpxComponentState",
#               "value": "INITIALIZED"
#             }
#           },
#           "method": {
#             "add": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str",
#                 "cfg": "cfg: Any"
#               },
#               "doc": "\n        Dynamically add a new instance at runtime, mirroring _populate logic for a single entry.\n        Returns the newly created component (or existing if already present).\n        "
#             },
#             "add_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": "Prevent adding itself as a child"
#             },
#             "close": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Convenience alias for destroy() to support 'with' or resource idioms."
#             },
#             "delete_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": "Destroy and remove a child component by reference."
#             },
#             "destroy": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Deep-destroy the component and all descendants.\n\n        This method is idempotent:\n        - Subsequent calls after the first successful destroy() are no-ops.\n        Cleanup order:\n        1) Transition \u2192 DESTROYING\n        2) Stop this component (best-effort) and trigger on_destroy hooks\n        3) Recursively destroy children (snapshot to avoid mutation while iterating)\n        4) Detach from parent\n        5) Call release() hook\n        6) Clear hooks/children references\n        7) Transition \u2192 DESTROYED\n        "
#             },
#             "disable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Disable the component. Lifecycle methods (prepare, run, start, stop)\n        become no-ops when the component is disabled.\n        "
#             },
#             "enable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#             },
#             "get": {
#               "type": "method",
#               "parameters": {
#                 "key": "key: str",
#                 "default": "default=None"
#               },
#               "doc": "\n        Get a child component by name, returning a default if not found.\n\n        Args:\n            key (str): Name of the child component.\n            default (Any): Value to return if the child is not found.\n\n        Returns:\n            Optional[SpxComponent]: The child component or the default.\n        "
#             },
#             "get_children": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return the internal dict of children keyed by name."
#             },
#             "get_children_list": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return a list of child components."
#             },
#             "get_hierarchy": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str"
#               },
#               "doc": "\n        Get all registered hook components for the given event name.\n        "
#             },
#             "get_parent": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_path": {
#               "type": "method",
#               "parameters": {
#                 "delimiter": "delimiter: str = '/'"
#               },
#               "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#             },
#             "get_root": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "pause": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Pause the component and propagate to children."
#             },
#             "prepare": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Prepare the component and propagate to children."
#             },
#             "register_hook": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "hook_component": "hook_component: 'SpxComponent'"
#               },
#               "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#             },
#             "release": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#             },
#             "remove": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str"
#               },
#               "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#             },
#             "remove_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": null
#             },
#             "reset": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Reset the component and propagate to children."
#             },
#             "run": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Run the component and propagate to children."
#             },
#             "start": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Start the component and propagate to children."
#             },
#             "stop": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Stop the component and propagate to children."
#             },
#             "trigger_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
# ...
#             },
#             "enable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#             },
#             "get": {
#               "type": "method",
#               "parameters": {
#                 "key": "key: str",
#                 "default": "default=None"
#               },
#               "doc": "\n        Get a child component by name, returning a default if not found.\n\n        Args:\n            key (str): Name of the child component.\n            default (Any): Value to return if the child is not found.\n\n        Returns:\n            Optional[SpxComponent]: The child component or the default.\n        "
#             },
#             "get_children": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return the internal dict of children keyed by name."
#             },
#             "get_children_list": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return a list of child components."
#             },
#             "get_hierarchy": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str"
#               },
#               "doc": "\n        Get all registered hook components for the given event name.\n        "
#             },
#             "get_parent": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_path": {
#               "type": "method",
#               "parameters": {
#                 "delimiter": "delimiter: str = '/'"
#               },
#               "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#             },
#             "get_root": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "is_running": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "pause": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Pause the component and propagate to children."
#             },
#             "prepare": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Prepare the component and propagate to children."
#             },
#             "register_hook": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "hook_component": "hook_component: 'SpxComponent'"
#               },
#               "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#             },
#             "release": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#             },
#             "remove": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str"
#               },
#               "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#             },
#             "remove_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": null
#             },
#             "reset": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Reset the timer to its initial configuration.\n        The timer is paused; accumulated elapsed time equals `initial_time`.\n        "
#             },
#             "run": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Run the component and propagate to children."
#             },
#             "start": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "stop": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "trigger_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Invoke all hooks registered under the given event.\n        Failures are emitted as diagnostics (bubble=False) and do not break lifecycle.\n        "
#             },
#             "update": {
#               "type": "method",
#               "parameters": {
#                 "cfg": "cfg: Union[Dict, List]"
#               },
#               "doc": "Forwards to the subclass hook _populate."
#             }
#           },
#           "children": []
#         },
#         {
#           "name": "polling",
#           "attr": {
#             "definition": {
#               "type": "dict",
#               "value": {}
#             },
#             "destroyed": {
#               "type": "bool",
#               "value": false,
#               "is_property": true,
#               "has_setter": false
#             },
#             "enabled": {
#               "type": "bool",
#               "value": true,
#               "is_property": true,
#               "has_setter": true
#             },
#             "hooks": {
#               "type": "dict",
#               "value": {}
#             },
#             "interval": {
#               "type": "float",
#               "value": 0.1
#             },
#             "jitter": {
#               "type": "int",
#               "value": 0
#             },
#             "logger": {
#               "type": "Logger",
#               "value": "<non-serializable: Logger>"
#             },
#             "max_iterations": {
#               "type": "float",
#               "value": "inf"
#             },
#             "name": {
#               "type": "str",
#               "value": "polling"
#             },
#             "parent": {
#               "type": "SpxComponent",
#               "name": "test_pt_100"
#             },
#             "polling_counter": {
#               "type": "int",
#               "value": 0
#             },
#             "running": {
#               "type": "bool",
#               "value": false
#             },
#             "state": {
#               "type": "SpxComponentState",
#               "value": "INITIALIZED"
#             },
#             "thread": {
#               "type": "NoneType",
#               "value": null
#             }
#           },
#           "method": {
#             "add": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str",
#                 "cfg": "cfg: Any"
#               },
#               "doc": "\n        Dynamically add a new instance at runtime, mirroring _populate logic for a single entry.\n        Returns the newly created component (or existing if already present).\n        "
#             },
#             "add_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": "Prevent adding itself as a child"
#             },
#             "close": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Convenience alias for destroy() to support 'with' or resource idioms."
#             },
#             "delete_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": "Destroy and remove a child component by reference."
#             },
#             "destroy": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Deep-destroy the component and all descendants.\n\n        This method is idempotent:\n        - Subsequent calls after the first successful destroy() are no-ops.\n        Cleanup order:\n        1) Transition \u2192 DESTROYING\n        2) Stop this component (best-effort) and trigger on_destroy hooks\n        3) Recursively destroy children (snapshot to avoid mutation while iterating)\n        4) Detach from parent\n        5) Call release() hook\n        6) Clear hooks/children references\n        7) Transition \u2192 DESTROYED\n        "
#             },
#             "disable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Disable the component. Lifecycle methods (prepare, run, start, stop)\n        become no-ops when the component is disabled.\n        "
#             },
#             "enable": {
#               "type": "method",
#               "parameters": {},
#               "doc": "\n        Enable the component. Lifecycle methods (prepare, run, start, stop)\n        will execute when this component is enabled.\n        "
#             },
#             "get": {
#               "type": "method",
#               "parameters": {
#                 "key": "key: str",
#                 "default": "default=None"
#               },
#               "doc": "\n        Get a child component by name, returning a default if not found.\n\n        Args:\n            key (str): Name of the child component.\n            default (Any): Value to return if the child is not found.\n\n        Returns:\n            Optional[SpxComponent]: The child component or the default.\n        "
#             },
#             "get_children": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return the internal dict of children keyed by name."
#             },
#             "get_children_list": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Return a list of child components."
#             },
#             "get_hierarchy": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str"
#               },
#               "doc": "\n        Get all registered hook components for the given event name.\n        "
#             },
#             "get_parent": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "get_path": {
#               "type": "method",
#               "parameters": {
#                 "delimiter": "delimiter: str = '/'"
#               },
#               "doc": "\n        Public path helper used by diagnostics: returns the component path with a chosen delimiter.\n        Default delimiter is '/', e.g. 'root/child/grandchild'.\n        "
#             },
#             "get_root": {
#               "type": "method",
#               "parameters": {},
#               "doc": null
#             },
#             "pause": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Pause the component and propagate to children."
#             },
#             "prepare": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "Prepare the component and propagate to children."
#             },
#             "register_hook": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "hook_component": "hook_component: 'SpxComponent'"
#               },
#               "doc": "\n        Register a hook component to be triggered on the given event.\n        Prevents duplicate registrations of the same hook for the same event.\n        "
#             },
#             "release": {
#               "type": "method",
#               "parameters": {},
#               "doc": "Hook for subclasses to free external resources (sockets, threads, files, etc.).\n        Called exactly once by `destroy()` before children/hooks are cleared.\n        Default implementation does nothing and returns True.\n        Subclasses should override and return True when cleanup succeeds.\n        "
#             },
#             "remove": {
#               "type": "method",
#               "parameters": {
#                 "inst_name": "inst_name: str"
#               },
#               "doc": "\n        Remove the instance with the given name.\n\n        Backward compatible:\n        - If the child defines a destroy() method (all SpxComponents do), we call it\n          to ensure resources are freed, then detach it.\n        "
#             },
#             "remove_child": {
#               "type": "method",
#               "parameters": {
#                 "child": "child: 'SpxComponent'"
#               },
#               "doc": null
#             },
#             "reset": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Initialize or reinitialize polling parameters.\n        Returns True if reset completes.\n        "
#             },
#             "run": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Run method that can be overridden by subclasses.\n        This method is called by the polling loop.\n        By default, it does nothing and returns True.\n        "
#             },
#             "start": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Start the polling loop in a background thread.\n        Returns True if the thread is started or already running.\n        "
#             },
#             "stop": {
#               "type": "method",
#               "parameters": {
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Stop the polling loop and wait for the thread to finish.\n        Returns True once stopped.\n        "
#             },
#             "trigger_hooks": {
#               "type": "method",
#               "parameters": {
#                 "event": "event: str",
#                 "args": "*args",
#                 "kwargs": "**kwargs"
#               },
#               "doc": "\n        Invoke all hooks registered under the given event.\n        Failures are emitted as diagnostics (bubble=False) and do not break lifecycle.\n        "
#             },
#             "update": {
#               "type": "method",
#               "parameters": {
#                 "cfg": "cfg: Union[Dict, List]"
#               },
#               "doc": "Forwards to the subclass hook _populate."
#             }
#           },
#           "children": []
#         }
#       ]
#     }
#   ]
# }

# %%
temperatures = []
temperatures_raw = []
times = np.linspace(0, 10, 1000)

instance["polling"].disable()
instance["actions"]["saw"].disable()

instance.reset()
instance.prepare()

temperature = instance["attributes"]["temperature"]
timer = instance["timer"]

# Run the instance for each time step
for t in times:
    timer.time = t
    instance.run()
    temperatures.append(temperature.external_value)
    temperatures_raw.append(temperature.internal_value)
    # print (f"Time: {t:.2f}s, Temperature: {temperatures[-1]:.2f}°C, Raw: {temperatures_raw[-1]:.2f}°C")

# Plotting the results
fig = go.Figure()
fig.add_trace(go.Scatter(x=times, y=temperatures, mode='lines', name='Temperature'))
fig.add_trace(go.Scatter(x=times, y=temperatures_raw, mode='lines', name='Temperature Internal'))
fig.update_layout(
    title='Change of Temperature Over Time',
    xaxis_title='Time (s)',
    yaxis_title='Temperature (°C)',
    showlegend=True
)

fig.show()
